# %% [markdown]
# # Example 04: Xenium Panel Summary
#
# 该示例对应 `scripts/run_example_04.py`，用于生成 Xenium 基因面板统计、报告与可视化图表。
#
# **输出目录**：`results/examples/example04/`

# %%
import subprocess
from pathlib import Path

repo_root = Path.cwd().resolve().parent if Path.cwd().name == "notebooks" else Path.cwd().resolve()
print(f"Repo root: {repo_root}")
subprocess.run(["python", "scripts/run_example_04.py"], cwd=repo_root, check=True)
print("Done. See results/examples/example04/")
